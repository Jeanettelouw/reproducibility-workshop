# %% [markdown]
# # Clean KNN exploration (fill-in)
#
# **Research question:** How do feature scaling and the number of neighbours $k$
# affect KNN classification performance and its decision boundary?
#
# Complete the `# TODO` bodies in `reproducible_knn/data.py`, `model.py`, and
# `run.py` first. This notebook only *calls* those functions.
#
# Full experiment without Jupyter:
#
# ```bash
# python -m reproducible_knn.run
# ```

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import yaml
from sklearn.metrics import accuracy_score

from reproducible_knn.data import make_data, split_data
from reproducible_knn.model import choose_k, make_knn

# Works whether you started Jupyter in fill_in_repo/ or notebooks/
ROOT = Path.cwd()
if not (ROOT / "config.yaml").exists() and (ROOT.parent / "config.yaml").exists():
    ROOT = ROOT.parent

# %% [markdown]
# ## Load settings from `config.yaml`
#
# Numbers live in one file so you do not hunt through cells to change the seed or
# the $k$ grid.

# %%
with open(ROOT / "config.yaml") as f:
    cfg = yaml.safe_load(f)

print("seed =", cfg["seed"])
print("k_values =", cfg["k_values"])
print("use_scaling =", cfg["use_scaling"])
# Out:
# seed = 20240719
# k_values = [1, 3, 5, 15, 31]
# use_scaling = True

# %% [markdown]
# ## Data: generate + stratified split
#
# Requires `make_data` and `split_data` in `reproducible_knn/data.py`.
# Same seed → same data and same split.

# %%
X, y = make_data(
    n_samples=cfg["n_samples"],
    noise=cfg["noise"],
    scale_factor=cfg["scale_factor"],
    seed=cfg["seed"],
)
X_train, X_test, y_train, y_test = split_data(
    X, y, test_size=cfg["test_size"], seed=cfg["seed"]
)

print(f"n_train={len(y_train)}, n_test={len(y_test)}")

fig, ax = plt.subplots()
ax.scatter(X[:, 0], X[:, 1], c=y, cmap="coolwarm", edgecolors="k", s=20)
ax.set_title("Synthetic moons (feature 1 is stretched)")
ax.set_xlabel("feature 0")
ax.set_ylabel("feature 1")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 X, y = make_data(
#       2     n_samples=cfg["n_samples"],
#       3     noise=cfg["noise"],
#       4     scale_factor=cfg["scale_factor"],
#
# File ~/Documents/Admin/UP/STK880/reproducibility-workshop/fill_in_repo/reproducible_knn/data.py:19, in make_data(n_samples, noise, scale_factor, seed)
#       9 """Return features X and labels y.
#      10
#      11 Feature 1 is multiplied by scale_factor so distances are dominated by
#      12 that axis unless you scale inside a Pipeline later.
#      13 """
#      14 # TODO: generate two-moons data with make_moons(...).
#      15 #   - pass n_samples, noise, and random_state=seed
#      16 #   - convert X and y to numpy arrays (float / int)
#      17 #   - multiply column 1 of X by scale_factor
#      18 #   - return X, y
# ---> 19 raise NotImplementedError("TODO: implement make_data")
#
# NotImplementedError: TODO: implement make_data

# %% [markdown]
# ## Choose $k$ with cross-validation on the **training** set only
#
# Requires `choose_k` / `make_knn` in `reproducible_knn/model.py`.
# Scaling (if enabled) must live inside a `Pipeline`. Do not use the test set here.

# %%
best_k, cv_results = choose_k(
    X_train,
    y_train,
    k_values=cfg["k_values"],
    use_scaling=cfg["use_scaling"],
    seed=cfg["seed"],
    cv_folds=cfg["cv_folds"],
)
display(cv_results)
print("best_k =", best_k)

# %% [markdown]
# ## Fit the chosen model and score the test set **once**

# %%
model = make_knn(k=best_k, use_scaling=cfg["use_scaling"])
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("test accuracy =", float(accuracy_score(y_test, y_pred)))

# %% [markdown]
# ## Reproduce without this notebook
#
# After you finish `run_experiment` in `reproducible_knn/run.py`:
#
# ```bash
# python -m reproducible_knn.run
# ```
#
# That writes `outputs/run/metrics.json`. Run twice with the same seed and compare.
